# %% [markdown]
# <a href="https://colab.research.google.com/github/Jageshc49/Capston-Loan_Defaulter__Project-/blob/main/Capston(Loan_Defaulter__Project).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/Loan_Defaulter (1).csv')

# %%
df.head()
# Out:
#          ID Client_Income  Car_Owned  Bike_Owned  Active_Loan  House_Own  \
# 0  12142509          6750        0.0         0.0          1.0        0.0
# 1  12138936         20250        1.0         0.0          1.0        NaN
# 2  12181264         18000        0.0         0.0          1.0        0.0
# 3  12188929         15750        0.0         0.0          1.0        1.0
# 4  12133385         33750        1.0         0.0          1.0        0.0
#
#    Child_Count Credit_Amount Loan_Annuity Accompany_Client  ...  \
# 0          0.0      61190.55      3416.85            Alone  ...
# 1          0.0         15282      1826.55            Alone  ...
# 2          1.0      59527.35       2788.2            Alone  ...
# 3          0.0       53870.4      2295.45            Alone  ...
# 4          2.0      133988.4      3547.35            Alone  ...
#
#   Client_Permanent_Match_Tag Client_Contact_Work_Tag       Type_Organization  \
# ...

# %%
df.tail()
# Out:
#               ID Client_Income  Car_Owned  Bike_Owned  Active_Loan  House_Own  \
# 121851  12207714         29250        0.0         0.0          NaN        1.0
# 121852  12173765         15750        0.0         1.0          1.0        0.0
# 121853  12103937          8100        0.0         1.0          0.0        1.0
# 121854  12170623         38250        1.0         1.0          0.0        1.0
# 121855  12105610          9000        1.0         1.0          1.0        1.0
#
#         Child_Count Credit_Amount Loan_Annuity Accompany_Client  ...  \
# 121851          0.0        107820       3165.3         Relative  ...
# 121852          0.0        104256      3388.05            Alone  ...
# 121853          1.0       55107.9      2989.35            Alone  ...
# 121854          0.0         45000      2719.35            Alone  ...
# 121855          1.0      62428.95      4201.65            Alone  ...
#
#        Client_Permanent_Match_Tag Client_Contact_Work_Tag  \
# ...

# %%
df.dtypes
# Out:
# ID                              int64
# Client_Income                  object
# Car_Owned                     float64
# Bike_Owned                    float64
# Active_Loan                   float64
# House_Own                     float64
# Child_Count                   float64
# Credit_Amount                  object
# Loan_Annuity                   object
# Accompany_Client               object
# Client_Income_Type             object
# Client_Education               object
# Client_Marital_Status          object
# Client_Gender                  object
# Loan_Contract_Type             object
# Client_Housing_Type            object
# Population_Region_Relative     object
# Age_Days                       object
# Employed_Days                  object
# Registration_Days              object
# ID_Days                        object
# Own_House_Age                 float64
# Mobile_Tag                      int64
# Homephone_Tag                   int64
# Workphone_Working               int64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121856 entries, 0 to 121855
# Data columns (total 40 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   ID                          121856 non-null  int64
#  1   Client_Income               118249 non-null  object
#  2   Car_Owned                   118275 non-null  float64
#  3   Bike_Owned                  118232 non-null  float64
#  4   Active_Loan                 118221 non-null  float64
#  5   House_Own                   118195 non-null  float64
#  6   Child_Count                 118218 non-null  float64
#  7   Credit_Amount               118224 non-null  object
#  8   Loan_Annuity                117044 non-null  object
#  9   Accompany_Client            120110 non-null  object
#  10  Client_Income_Type          118155 non-null  object
#  11  Client_Education            118211 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# ID                                0
# Client_Income                  3607
# Car_Owned                      3581
# Bike_Owned                     3624
# Active_Loan                    3635
# House_Own                      3661
# Child_Count                    3638
# Credit_Amount                  3632
# Loan_Annuity                   4812
# Accompany_Client               1746
# Client_Income_Type             3701
# Client_Education               3645
# Client_Marital_Status          3473
# Client_Gender                  2413
# Loan_Contract_Type             3651
# Client_Housing_Type            3687
# Population_Region_Relative     4857
# Age_Days                       3600
# Employed_Days                  3649
# Registration_Days              3614
# ID_Days                        5968
# Own_House_Age                 80095
# Mobile_Tag                        0
# Homephone_Tag                     0
# Workphone_Working                 0
# Client_Occupation             41435
# ...

# %%
a = df.isnull().sum()
perc = (a/(len(df)))*100
perc = pd.DataFrame(perc,columns=['Age of missing data'])
perc
# Out:
#                             Age of missing data
# ID                                     0.000000
# Client_Income                          2.960051
# Car_Owned                              2.938715
# Bike_Owned                             2.974002
# Active_Loan                            2.983029
# House_Own                              3.004366
# Child_Count                            2.985491
# Credit_Amount                          2.980567
# Loan_Annuity                           3.948923
# Accompany_Client                       1.432839
# Client_Income_Type                     3.037191
# Client_Education                       2.991236
# Client_Marital_Status                  2.850085
# Client_Gender                          1.980206
# Loan_Contract_Type                     2.996159
# Client_Housing_Type                    3.025702
# Population_Region_Relative             3.985852
# Age_Days                               2.954307
# Employed_Days                          2.994518
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Client_Income', 'Car_Owned', 'Bike_Owned', 'Active_Loan',
#        'House_Own', 'Child_Count', 'Credit_Amount', 'Loan_Annuity',
#        'Accompany_Client', 'Client_Income_Type', 'Client_Education',
#        'Client_Marital_Status', 'Client_Gender', 'Loan_Contract_Type',
#        'Client_Housing_Type', 'Population_Region_Relative', 'Age_Days',
#        'Employed_Days', 'Registration_Days', 'ID_Days', 'Own_House_Age',
#        'Mobile_Tag', 'Homephone_Tag', 'Workphone_Working', 'Client_Occupation',
#        'Client_Family_Members', 'Cleint_City_Rating',
#        'Application_Process_Day', 'Application_Process_Hour',
#        'Client_Permanent_Match_Tag', 'Client_Contact_Work_Tag',
#        'Type_Organization', 'Score_Source_1', 'Score_Source_2',
#        'Score_Source_3', 'Social_Circle_Default', 'Phone_Change',
#        'Credit_Bureau', 'Default'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121856 entries, 0 to 121855
# Data columns (total 40 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   ID                          121856 non-null  int64
#  1   Client_Income               118249 non-null  object
#  2   Car_Owned                   118275 non-null  float64
#  3   Bike_Owned                  118232 non-null  float64
#  4   Active_Loan                 118221 non-null  float64
#  5   House_Own                   118195 non-null  float64
#  6   Child_Count                 118218 non-null  float64
#  7   Credit_Amount               118224 non-null  object
#  8   Loan_Annuity                117044 non-null  object
#  9   Accompany_Client            120110 non-null  object
#  10  Client_Income_Type          118155 non-null  object
#  11  Client_Education            118211 non-null  object
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df['Client_Income'] = df['Client_Income'].replace('$',np.nan).astype('float')

# %%
df['Client_Income'].fillna(df['Client_Income'].median(),inplace=True)

# %%
df['Credit_Amount'] = df['Credit_Amount'].replace('$',np.nan).astype('float')

# %%
df['Credit_Amount'].fillna(df['Credit_Amount'].median(),inplace=True)

# %%
df['Loan_Annuity'] = df['Loan_Annuity'].replace(['$','#VALUE!'],np.nan).astype('float')

# %%
df['Loan_Annuity'].fillna(df['Loan_Annuity'].median(),inplace=True)

# %%
df['Accompany_Client'] = df['Accompany_Client'].replace(['Alone','Relative','Others','Kids','Partner','##','Group'],np.nan).astype('float')

# %%
df['Accompany_Client'].fillna(df['Accompany_Client'].median(),inplace=True)

# %%
df['Loan_Contract_Type'] = df['Loan_Contract_Type'].replace(['CL','RL'],np.nan).astype(float)

# %%
df['Loan_Contract_Type'].fillna(df['Loan_Contract_Type'].median(),inplace=True)

# %%
df['Population_Region_Relative'] = df['Population_Region_Relative'].replace(['@','#'],np.nan).astype(float)

# %%
df['Population_Region_Relative'].fillna(df['Population_Region_Relative'].median(),inplace=True)

# %%
df['Age_Days'] = df['Age_Days'].replace(['X','x'],np.nan).astype(float)

# %%
df['Age_Days'].fillna(df['Age_Days'].median(),inplace=True)

# %%
df['Employed_Days'] = df['Employed_Days'].replace(['x'],np.nan).astype(float)

# %%
df['Employed_Days'].fillna(df['Employed_Days'].median(),inplace=True)

# %%
df['Registration_Days'] = df['Registration_Days'].replace(['x'],np.nan).astype(float)

# %%
df['Registration_Days'].fillna(df['Registration_Days'].median(),inplace=True)

# %%
df['ID_Days'] = df['ID_Days'].replace(['x'],np.nan).astype(float)

# %%
df['ID_Days'].fillna(df['ID_Days'].median(),inplace=True)

# %%
df['Client_Permanent_Match_Tag'] = df['Client_Permanent_Match_Tag'].replace(['Yes','No'],np.nan).astype(float)

# %%
df['Client_Permanent_Match_Tag'].fillna(df['Client_Permanent_Match_Tag'].median(),inplace=True)

# %%
df['Score_Source_3'] = df['Score_Source_3'].replace(['&'],np.nan).astype(float)

# %%
df['Score_Source_3'].fillna(df['Score_Source_3'].median(),inplace=True)

# %%
df['Car_Owned']=le.fit_transform(df['Car_Owned'])

# %%
df['Bike_Owned']=le.fit_transform(df['Bike_Owned'])

# %%
df['Active_Loan']=le.fit_transform(df['Active_Loan'])

# %%
df['Active_Loan']=le.fit_transform(df['Active_Loan'])

# %%
df['House_Own']=le.fit_transform(df['House_Own'])

# %%
df['Child_Count']=le.fit_transform(df['Child_Count'])

# %%
df['Accompany_Client']=le.fit_transform(df['Accompany_Client'])

# %%
df['Own_House_Age']=le.fit_transform(df['Own_House_Age'])

# %%
df['Client_Permanent_Match_Tag']=le.fit_transform(df['Client_Permanent_Match_Tag'])

# %%
df['Application_Process_Hour']=le.fit_transform(df['Application_Process_Hour'])

# %%
df['Application_Process_Day']=le.fit_transform(df['Application_Process_Day'])

# %%
df['Cleint_City_Rating']=le.fit_transform(df['Cleint_City_Rating'])

# %%
df['Client_Family_Members']=le.fit_transform(df['Client_Family_Members'])

# %%
df['Score_Source_1']=le.fit_transform(df['Score_Source_1'])

# %%
df['Score_Source_2']=le.fit_transform(df['Score_Source_2'])

# %%
df['Social_Circle_Default']=le.fit_transform(df['Social_Circle_Default'])

# %%
df['Phone_Change']=le.fit_transform(df['Phone_Change'])

# %%
df['Credit_Bureau']=le.fit_transform(df['Credit_Bureau'])

# %%
df['Client_Contact_Work_Tag']=le.fit_transform(df['Client_Contact_Work_Tag'])

# %%
df['Loan_Contract_Type']=le.fit_transform(df['Loan_Contract_Type'])

# %%
df['Client_Income_Type']=le.fit_transform(df['Client_Income_Type'])

# %%
df['Client_Education']=le.fit_transform(df['Client_Education'])

# %%
df['Client_Marital_Status']=le.fit_transform(df['Client_Marital_Status'])

# %%
df['Client_Gender']=le.fit_transform(df['Client_Gender'])

# %%
df['Client_Housing_Type']=le.fit_transform(df['Client_Housing_Type'])

# %%
df['Client_Occupation']=le.fit_transform(df['Client_Occupation'])

# %%
df['Type_Organization']=le.fit_transform(df['Type_Organization'])

# %%
df.isna().sum()
# Out:
# ID                            0
# Client_Income                 0
# Car_Owned                     0
# Bike_Owned                    0
# Active_Loan                   0
# House_Own                     0
# Child_Count                   0
# Credit_Amount                 0
# Loan_Annuity                  0
# Accompany_Client              0
# Client_Income_Type            0
# Client_Education              0
# Client_Marital_Status         0
# Client_Gender                 0
# Loan_Contract_Type            0
# Client_Housing_Type           0
# Population_Region_Relative    0
# Age_Days                      0
# Employed_Days                 0
# Registration_Days             0
# ID_Days                       0
# Own_House_Age                 0
# Mobile_Tag                    0
# Homephone_Tag                 0
# Workphone_Working             0
# Client_Occupation             0
# Client_Family_Members         0
# Cleint_City_Rating            0
# Application_Process_Day       0
# ...

# %%
df.drop(['ID','Own_House_Age','Registration_Days','ID_Days','Workphone_Working','Homephone_Tag','Mobile_Tag','Score_Source_1','Score_Source_2','Score_Source_3','Phone_Change','Population_Region_Relative','Social_Circle_Default','Client_Permanent_Match_Tag','Loan_Contract_Type','Client_Contact_Work_Tag','Age_Days','Accompany_Client'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121856 entries, 0 to 121855
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Client_Income             121856 non-null  float64
#  1   Car_Owned                 121856 non-null  int64
#  2   Bike_Owned                121856 non-null  int64
#  3   Active_Loan               121856 non-null  int64
#  4   House_Own                 121856 non-null  int64
#  5   Child_Count               121856 non-null  int64
#  6   Credit_Amount             121856 non-null  float64
#  7   Loan_Annuity              121856 non-null  float64
#  8   Client_Income_Type        121856 non-null  int64
#  9   Client_Education          121856 non-null  int64
#  10  Client_Marital_Status     121856 non-null  int64
#  11  Client_Gender             121856 non-null  int64
#  12  Client_Housing_Type       121856 non-null  int64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121856 entries, 0 to 121855
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Client_Income             121856 non-null  float64
#  1   Car_Owned                 121856 non-null  int64
#  2   Bike_Owned                121856 non-null  int64
#  3   Active_Loan               121856 non-null  int64
#  4   House_Own                 121856 non-null  int64
#  5   Child_Count               121856 non-null  int64
#  6   Credit_Amount             121856 non-null  float64
#  7   Loan_Annuity              121856 non-null  float64
#  8   Client_Income_Type        121856 non-null  int64
#  9   Client_Education          121856 non-null  int64
#  10  Client_Marital_Status     121856 non-null  int64
#  11  Client_Gender             121856 non-null  int64
#  12  Client_Housing_Type       121856 non-null  int64
# ...

# %%
corr = df.corr()
corr
# Out:
#                           Client_Income  Car_Owned  Bike_Owned  Active_Loan  \
# Client_Income                  1.000000   0.144036   -0.002426    -0.000535
# Car_Owned                      0.144036   1.000000    0.000340    -0.000034
# Bike_Owned                    -0.002426   0.000340    1.000000    -0.000432
# Active_Loan                   -0.000535  -0.000034   -0.000432     1.000000
# House_Own                      0.003487  -0.004166    0.000554    -0.002553
# Child_Count                    0.004207   0.026870    0.003001     0.002959
# Credit_Amount                  0.317541   0.095528    0.005192    -0.000770
# Loan_Annuity                   0.390341   0.117950    0.000789    -0.001532
# Client_Income_Type            -0.137085  -0.020794   -0.002185     0.000216
# Client_Education              -0.191581  -0.074883    0.003945    -0.000894
# Client_Marital_Status         -0.028387  -0.061228   -0.002988     0.004122
# ...

# %%
df.skew()
# Out:
# Client_Income               37.706876
# Car_Owned                    0.982016
# Bike_Owned                   1.033753
# Active_Loan                  0.350442
# House_Own                   -0.326924
# Child_Count                  4.825754
# Credit_Amount                1.265144
# Loan_Annuity                 1.730310
# Client_Income_Type          -0.389815
# Client_Education            -0.996399
# Client_Marital_Status        1.676038
# Client_Gender                0.745539
# Client_Housing_Type          3.703401
# Employed_Days                1.726868
# Client_Occupation           -0.241958
# Client_Family_Members        5.131305
# Cleint_City_Rating           0.649401
# Application_Process_Day      0.067262
# Application_Process_Hour     0.613451
# Type_Organization           -0.057370
# Credit_Bureau                1.715976
# Default                      3.076618
# dtype: float64

# %%
import seaborn
import matplotlib.pyplot as plt
 import seaborn as sns

# %%
plt.figure(figsize=(27,14))
plt.title('Correlation_Matrix_Loan_Default',fontsize=20)
sns.heatmap(corr.drop(['Default'],axis=1).drop(['Default'],axis=0),annot=True,fmt='g',cmap='RdYlGn')
plt.show()

# %%
sns.boxplot(df.Loan_Annuity)
plt.show()

# %%
df.Loan_Annuity.describe()
# Out:
# count    121856.000000
# mean       2712.482001
# std        1432.884876
# min         217.350000
# 25%        1687.500000
# 50%        2499.750000
# 75%        3407.962500
# max       22500.000000
# Name: Loan_Annuity, dtype: float64

# %%
sns.scatterplot(x='Credit_Amount',y='Loan_Annuity',data=df,hue="Default")
plt.show()

# %%
sns.scatterplot(y='Client_Income',x='Car_Owned',data=df,hue="Default")
plt.show()

# %%
sns.barplot(y = 'Client_Income',x ='Client_Income_Type',hue = 'Default',data = df)
plt.show()

# %%
sns.barplot(y = 'Client_Income',x ='Client_Gender',hue = 'Default',data = df)
plt.show()

# %%
features = ['Client_Gender', 'Client_Income_Type', 'Client_Education','Client_Marital_Status','Client_Housing_Type','Client_Occupation']
plt.figure(figsize = (20, 40))

plt.subplots_adjust(hspace=0.8)
for i in enumerate(features):
    plt.subplot(5, 2, i[0]+1)
    sns.countplot(x = i[1], hue = 'Default', data = df)
    plt.xticks(rotation = 45)

# %%
df.hist(figsize=(25,22))
plt.show()

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

# %%
x = df.drop('Default',axis=1)
y = df[['Default']]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=1)

# %%
x_train.shape
# Out:
# (85299, 21)

# %%
x_test.shape
# Out:
# (36557, 21)

# %%
y_train.shape
# Out:
# (85299, 1)

# %%
y_test.shape
# Out:
# (36557, 1)

# %% [markdown]
# # **KNN**

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
Knn = KNeighborsClassifier(n_neighbors=3)

# %%
Knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
Knn_pred = Knn.predict(x_test)

# %%
Knn_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
accuracy_score(y_test,Knn_pred)*100
# Out:
# 89.82137483929206

# %%
cf_knn = confusion_matrix(y_test,Knn_pred)

# %%
cf_knn
# Out:
# array([[32650,   913],
#        [ 2808,   186]])

# %%
plt.figure(figsize=(10,5))
plt.title('Confusion_Matrix_KNN',fontsize=20)
sns.heatmap(cf_knn,annot=True,cmap='Reds',fmt='g')
plt.show()

# %%
print(classification_report(y_test,Knn_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.95     33563
#            1       0.17      0.06      0.09      2994
#
#     accuracy                           0.90     36557
#    macro avg       0.55      0.52      0.52     36557
# weighted avg       0.86      0.90      0.88     36557

# %% [markdown]
# # **Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr_pred = lr.predict(x_test)

# %%
lr_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
lr.score(x_train,y_train)*100
# Out:
# 91.96825285173331

# %%
lr.score(x_test,y_test)*100
# Out:
# 91.81005005881227

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
accuracy_score(y_test,lr_pred)*100
# Out:
# 91.81005005881227

# %%
cf_lr = confusion_matrix(y_test,lr_pred)

# %%
cf_lr.shape
# Out:
# (2, 2)

# %%
cf_lr
# Out:
# array([[33563,     0],
#        [ 2994,     0]])

# %%
plt.figure(figsize=(10,5))
plt.title('Confusion_Matrix_LR',fontsize=20)
sns.heatmap(cf_lr,annot=True,cmap='Blues',fmt='g')
plt.show()

# %%
print(classification_report(y_test,lr_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96     33563
#            1       0.00      0.00      0.00      2994
#
#     accuracy                           0.92     36557
#    macro avg       0.46      0.50      0.48     36557
# weighted avg       0.84      0.92      0.88     36557

# %% [markdown]
# # **Naive_Bayes**

# %%
from sklearn.naive_bayes import GaussianNB

# %%
NB = GaussianNB()

# %%
NB.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
NB_pred = NB.predict(x_test)

# %%
NB_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
accuracy_score(y_test,NB_pred)*100
# Out:
# 91.81005005881227

# %%
cf_NB = confusion_matrix(y_test,NB_pred)
cf_NB
# Out:
# array([[33563,     0],
#        [ 2994,     0]])

# %%
plt.figure(figsize=(10,5))
plt.title('Confusion_Matrix_of_NB',fontsize=20)
sns.heatmap(cf_NB,cmap = 'OrRd',annot=True,fmt='g')
plt.show()

# %%
print(classification_report(y_test,NB_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96     33563
#            1       0.00      0.00      0.00      2994
#
#     accuracy                           0.92     36557
#    macro avg       0.46      0.50      0.48     36557
# weighted avg       0.84      0.92      0.88     36557

# %% [markdown]
# # **Decision Tree**

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier(criterion= 'gini',max_depth=3)

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
model_pred = model.predict(x_test)

# %%
model.score(x_train,y_train)*100
# Out:
# 91.96825285173331

# %%
model.score(x_test,y_test)*100
# Out:
# 91.81005005881227

# %%
cf = confusion_matrix(y_test,model_pred)

# %%
cf.shape
# Out:
# (2, 2)

# %%
cf
# Out:
# array([[33563,     0],
#        [ 2994,     0]])

# %%
plt.figure(figsize=(10,5))
plt.title('Confusion_Matrix_DT',fontsize=20)
sns.heatmap(cf,annot=True,cmap='Blues',fmt='g')
plt.show()

# %%
print(classification_report(y_test,model_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96     33563
#            1       0.00      0.00      0.00      2994
#
#     accuracy                           0.92     36557
#    macro avg       0.46      0.50      0.48     36557
# weighted avg       0.84      0.92      0.88     36557

# %% [markdown]
# # **Plotting Dicison Tree**

# %%
from sklearn.tree import plot_tree

# %%
f = list(x_train)
c = ['No','Yes']
fig,axes = plt.subplots(nrows=1,ncols=1,figsize=(20,12),dpi=300)
plot_tree(model,feature_names=f,class_names=c,filled=True)
plt.title('Decision_Tree_Classifier_Entropy',fontsize=25)
plt.show()

# %% [markdown]
# # **Ensembles Technique**

# %%
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=500,criterion='entropy',max_depth=11)

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=11, n_estimators=500)

# %%
rf_pred = rf.predict(x_test)

# %%
rf.score(x_test,y_test)*100
# Out:
# 91.81005005881227

# %%
rf.score(x_train,y_train)*100
# Out:
# 91.96825285173331

# %%
# Bagging
from sklearn.ensemble import BaggingClassifier

# %%
bg = BaggingClassifier(base_estimator=model,n_estimators=100,random_state=1)

# %%
bg.fit(x_train,y_train)
# Out:
# BaggingClassifier(base_estimator=DecisionTreeClassifier(max_depth=3),
#                   n_estimators=100, random_state=1)

# %%
bg.pred = bg.predict(x_test)

# %%
bg.score(x_test,y_test)*100
# Out:
# 91.81005005881227

# %%
bg.score(x_train,y_train)*100
# Out:
# 91.96825285173331

# %%
# Ada Boosting
from sklearn.ensemble import AdaBoostClassifier

# %%
ada = AdaBoostClassifier()

# %%
ada.fit(x_train,y_train)
# Out:
# AdaBoostClassifier()

# %%
ada.pred = ada.predict(x_test)

# %%
ada.score(x_test,y_test)*100
# Out:
# 91.81005005881227

# %%
ada.score(x_train,y_train)*100
# Out:
# 91.96825285173331

# %%
# Gradient Boosting Classifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbcl = GradientBoostingClassifier()

# %%
gbcl.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
gbcl.pred = gbcl.predict(x_test)

# %%
gbcl.score(x_train,y_train)*100
# Out:
# 91.97645927853785

# %%
gbcl.score(x_test,y_test)*100
# Out:
# 91.81278551303443

# %%
# XGB Boost
import xgboost as xgb

# %%
xgbc = xgb.XGBClassifier()

# %%
xgbc.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
xgbc.pred = xgbc.predict(x_test)

# %%
xgbc.score(x_train,y_train)*100
# Out:
# 92.40084877900092

# %%
xgbc.score(x_test,y_test)*100
# Out:
# 91.78816642503487

# %%
# LGBM
import lightgbm as lgb

# %%
lgbmc = lgb.LGBMClassifier()

# %%
lgbmc.fit(x_train,y_train)
# Out:
# LGBMClassifier()

# %%
lgbmc.pred = lgbmc.predict(x_test)

# %%
lgbmc.score(x_train,y_train)*100
# Out:
# 91.99756151889237

# %%
lgbmc.score(x_test,y_test)*100
# Out:
# 91.82099187570097

# %%
! pip install catboost
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.6/76.6 MB 9.0 MB/s eta 0:00:00
# ...

# %%
# Catboost
import catboost as ctb

# %%
ctb = ctb.CatBoostClassifier()

# %%
ctb.fit(x_train,y_train)
# Out:
# Learning rate set to 0.068778
# 0:	learn: 0.6246376	total: 90.2ms	remaining: 1m 30s
# 1:	learn: 0.5676847	total: 122ms	remaining: 1m 1s
# 2:	learn: 0.5199440	total: 152ms	remaining: 50.4s
# 3:	learn: 0.4800071	total: 184ms	remaining: 45.9s
# 4:	learn: 0.4474369	total: 215ms	remaining: 42.9s
# 5:	learn: 0.4198903	total: 241ms	remaining: 40s
# 6:	learn: 0.3967361	total: 272ms	remaining: 38.6s
# 7:	learn: 0.3779119	total: 300ms	remaining: 37.1s
# 8:	learn: 0.3622109	total: 326ms	remaining: 35.9s
# 9:	learn: 0.3486776	total: 353ms	remaining: 35s
# 10:	learn: 0.3370904	total: 397ms	remaining: 35.7s
# 11:	learn: 0.3274484	total: 423ms	remaining: 34.8s
# 12:	learn: 0.3192323	total: 444ms	remaining: 33.7s
# 13:	learn: 0.3119937	total: 472ms	remaining: 33.3s
# 14:	learn: 0.3061233	total: 503ms	remaining: 33.1s
# 15:	learn: 0.3010073	total: 527ms	remaining: 32.4s
# 16:	learn: 0.2965968	total: 553ms	remaining: 32s
# 17:	learn: 0.2926194	total: 582ms	remaining: 31.7s
# ...

# %%
ctb.pred = ctb.predict(x_test)

# %%
ctb.score(x_train,y_train)*100
# Out:
# 92.28244176367836

# %%
ctb.score(x_test,y_test)*100
# Out:
# 91.81825642147878
